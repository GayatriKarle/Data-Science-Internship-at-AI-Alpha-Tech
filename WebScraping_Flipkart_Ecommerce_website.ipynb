# %% [markdown]
# <a href="https://colab.research.google.com/github/GayatriKarle/Data-Science-Internship-at-AI-Alpha-Tech/blob/main/WebScraping_Flipkart_Ecommerce_website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is web scraping?**

# %% [markdown]
# * Web scraping generally is the process of extracting data from the web; you can analyze the data and extract useful information.
#
# * Also, you can store the scraped data in a database or any kind of tabular format such as CSV, XLS, etc., so you can access that information easily.
#
# * The scraped data can be passed to a library like NLTK for further processing to understand what the page is talking about.

# %% [markdown]
# **Benifits of Web Sraping**

# %% [markdown]
# * You might wonder why I should scrape the web and I have Google? Well, we don’t reinvent the wheel here. It is not for creating search engines only.
#
# * You can scrape your competitor’s web pages and analyze the data and see what kind of products your competitor’s clients are happy with their responses. All this for FREE.
#
# * A successful SEO tool like Moz that scraps and crawls the entire web and process the data for you so you can see people’s interest and how to compete with others in your field to be on the top.
#
# * These are just some simple uses. The scraped data means making money.

# %% [markdown]
# **BeautifulSoup4 Library**

# %% [markdown]
# * Beautiful Soup is a Python library designed for quick turnaround projects like screen-scraping. Three features make it powerful:
#
# * 1) Beautiful Soup provides a few simple methods and Pythonic idioms for navigating, searching, and modifying a parse tree: a toolkit for dissecting a document and extracting what you need. It doesn't take much code to write an application
#
# * 2) Beautiful Soup automatically converts incoming documents to Unicode and outgoing documents to UTF-8. You don't have to think about encodings, unless the document doesn't specify an encoding and Beautiful Soup can't detect one. Then you just have to specify the original encoding.
#
# * 3) Beautiful Soup sits on top of popular Python parsers like lxml and html5lib, allowing you to try out different parsing strategies or trade speed for flexibility.
#
# * Beautiful Soup parses anything you give it, and does the tree traversal stuff for you. You can tell it "Find all the links", or "Find all the links of class externalLink", or "Find all the links whose urls match "foo.com", or "Find the table heading that's got bold text, then give me that text."
#
# * Valuable data that was once locked up in poorly-designed websites is now within your reach. Projects that would have taken hours take only minutes with Beautiful Soup.

# %% [markdown]
# **Is web Crawler and Web Scraping are same?**

# %% [markdown]
# * There is a very subtle difference between web crawler and web scraping:
# * 1) Simple terms Web crawling is the process of repetitively finding and fetching hyperlinks starting from a list of starting URLs. Broadly speaking web crawling is a process of locating information on worldwide web, indexing all the words in a document, adding them to a database. then following all hyperlinks and indexes and even adding that information to the database. Major search engines like Yahoo, Google, Bing etc all are such a program which is also known as a web spide or a bot.
# * 2) but when you see on the other Web Scraping is a process of automatically requesting a web document and collecting information from it. strictly speaking to do web scraping you have to do some degree of web crawling to move around the web sites.
# * 3) Web crawling is generally what major search engine do for searching any kind of information.
# Web Scrapping is essentially targated at specific web sites for a specific data. for eg stock market data, business leads or supply products scraping anything like that.
# * 4) But an important thing to know is that web scraper can do things a web crawler wouldn't do for example they doesn't obey the robots.txt
# * 5) robots.txt- It is file that tell us what you can crawl and what you cannot. so web scraper does not obey that.
# * 6) Next is submit forms with data or execute JavaScript or transforming the data into required formband format or even saving the extracted data into database so there are the thing a web scraper can do but a web crawler cannot.

# %% [markdown]
# **1) Extract asian countries from table on Wikipedia Page:**

# %%
#Import a library to query a website:
import requests
wiki_link="https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area"
link=requests.get(wiki_link).text

# %%
print(link)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Asian countries by area - Wikipedia</title>
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(link,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Asian countries by area - Wikipedia</title>
# ...

# %% [markdown]
# *From prettify() i get a nested structure of HTML Page this will help me to see the structure of the HTML tags, this will also help you to know about the different available tags and how you can play with these and extract information .

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Asian countries by area - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.title     # To fetch title
# Out:
# <title>List of Asian countries by area - Wikipedia</title>

# %%
soup.title.string    #I just want List of Asian countries by area - Wikipedi
# Out:
# 'List of Asian countries by area - Wikipedia'

# %%
#To Fetch various links in this data
soup.a
# Out:
# <a id="top"></a>

# %% [markdown]
# *Here we get only one output but to extract all links which have a tags in it we use find_all()

# %%
soup.find_all("a")
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>,
#  <a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a>,
#  <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a>,
#  <a class="external text" href="https://en.wikipedia.org/w/index.php?title=List_of_Asian_countries_by_area&amp;action=edit">improve this article</a>,
# ...

# %% [markdown]
# **##To get all href links:**

# %%
all_link=soup.find_all("a")
for link in all_link:
    print(link.get('href'))
# Out:
# None
# #mw-head
# #searchInput
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Verifiability
# https://en.wikipedia.org/w/index.php?title=List_of_Asian_countries_by_area&action=edit
# /wiki/Help:Referencing_for_beginners
# //www.google.com/search?as_eq=wikipedia&q=%22List+of+Asian+countries+by+area%22
# //www.google.com/search?tbm=nws&q=%22List+of+Asian+countries+by+area%22+-wikipedia&tbs=ar:1
# //www.google.com/search?&q=%22List+of+Asian+countries+by+area%22&tbs=bkt:s&tbm=bks
# //www.google.com/search?tbs=bks:1&q=%22List+of+Asian+countries+by+area%22+-wikipedia
# //scholar.google.com/scholar?q=%22List+of+Asian+countries+by+area%22
# https://www.jstor.org/action/doBasicSearch?Query=%22List+of+Asian+countries+by+area%22&acc=on&wc=on
# /wiki/Help:Maintenance_template_removal
# /wiki/Asia
# /wiki/List_of_transcontinental_countries
# /wiki/Asterisk
# /wiki/Russia
# /wiki/European_Russia
# #cite_note-russiaTotalAreaByCIA-1
# /wiki/China
# /wiki/Taiwan
# /wiki/Hong_Kong
# /wiki/Macau
# ...

# %% [markdown]
# **To Extract information within all table tags:**

# %%
all_tables=soup.find_all('table')
print(all_tables)
# Out:
# [<table class="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove" role="presentation"><tbody><tr><td class="mbox-image"><div style="width:52px"><a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></div></td><td class="mbox-text"><div class="mbox-text-span">This article <b>needs additional citations for <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a></b>.<span class="hide-when-compact"> Please help <a class="external text" href="https://en.wikipedia.org/w/index.php?title=List_of_Asian_cou
# ...

# %%
right_table=soup.find('table',class_="wikitable sortable")       # To get wanted table
print(right_table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th rowspan="2">Rank
# </th>
# <th rowspan="2">Country
# </th>
# <th colspan="2">Area
# </th>
# <th class="unsortable" rowspan="2">Notes
# </th>
# <th rowspan="2">Facts
# </th></tr>
# <tr>
# <th>km²
# </th>
# <th>sq mi
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon" style="display:inline-block;width:25px;"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/></span> <a href="/wiki/Russia" title="Russia">Russia</a>*
# </td>
# <td data-sort-value="7013131291420000000" style="text-align:right;">13,129,142
# </td>
# ...

# %%
table_links=right_table.findAll('a')       # Here we used a tags because of countries are in a> tags
table_links
# Out:
# [<a href="/wiki/Russia" title="Russia">Russia</a>,
#  <a href="/wiki/European_Russia" title="European Russia">European Russia</a>,
#  <a href="#cite_note-russiaTotalAreaByCIA-1">[1]</a>,
#  <a href="/wiki/China" title="China">China</a>,
#  <a href="/wiki/Taiwan" title="Taiwan">Taiwan</a>,
#  <a href="/wiki/Hong_Kong" title="Hong Kong">Hong Kong</a>,
#  <a href="/wiki/Macau" title="Macau">Macau</a>,
#  <a href="/wiki/India" title="India">India</a>,
#  <a href="/wiki/Kazakhstan" title="Kazakhstan">Kazakhstan</a>,
#  <a href="/wiki/Saudi_Arabia" title="Saudi Arabia">Saudi Arabia</a>,
#  <a href="/wiki/Iran" title="Iran">Iran</a>,
#  <a href="/wiki/Mongolia" title="Mongolia">Mongolia</a>,
#  <a href="/wiki/Indonesia" title="Indonesia">Indonesia</a>,
#  <a href="/wiki/Western_New_Guinea" title="Western New Guinea">Indonesian New Guinea</a>,
#  <a href="/wiki/Oceania" title="Oceania">Oceania</a>,
#  <a href="/wiki/Pakistan" title="Pakistan">Pakistan</a>,
# ...

# %% [markdown]
# **Import countries to dataframe:**

# %%
country=[]           #To store countries we pass empty list
for links in table_links:
    country.append(links.get('title'))
print(country)
# Out:
# ['Russia', 'European Russia', None, 'China', 'Taiwan', 'Hong Kong', 'Macau', 'India', 'Kazakhstan', 'Saudi Arabia', 'Iran', 'Mongolia', 'Indonesia', 'Western New Guinea', 'Oceania', 'Pakistan', 'Turkey', 'East Thrace', 'Myanmar', 'Afghanistan', 'Yemen', 'Thailand', 'Turkmenistan', 'Uzbekistan', 'Iraq', 'Japan', 'Vietnam', 'Malaysia', 'Oman', 'Philippines', 'Laos', 'Kyrgyzstan', 'Syria', 'Golan Heights', 'Cambodia', 'Bangladesh', 'Nepal', 'Tajikistan', 'North Korea', 'South Korea', 'Jordan', 'United Arab Emirates', 'Azerbaijan', 'Caucasus', 'Europe', 'Asia', 'Georgia (country)', 'Caucasus', 'Europe', 'Asia', 'Sri Lanka', 'Egypt', 'Bhutan', 'Taiwan', 'Free area of the Republic of China', 'Armenia', 'Armenian highlands', 'Caucasus', 'Europe', 'Asia', 'Israel', 'West Bank', 'Gaza Strip', 'Golan Heights', 'Kuwait', 'East Timor', 'Qatar', 'Lebanon', 'Cyprus', 'Northern Cyprus', 'State of Palestine', 'West Bank', 'Gaza Strip', 'Brunei', 'Bahrain', 'Singapore', 'Maldives']

# %%
import pandas as pd
df=pd.DataFrame()
df['Country']=country
df
# Out:
#             Country
# 0            Russia
# 1   European Russia
# 2              None
# 3             China
# 4            Taiwan
# ..              ...
# 72       Gaza Strip
# 73           Brunei
# 74          Bahrain
# 75        Singapore
# 76         Maldives
#
# [77 rows x 1 columns]

# %% [markdown]
# **2) Automating webscraping amazon ecommerce:**

# %%
# !pip install autoscraper

# %%
from autoscraper import AutoScraper

# %%
amazon_url="https://www.amazon.in/s?k=iphone+under+1+lakh&crid=147R1PSWNQRKN&sprefix=iphone+under+1+lakh%2Caps%2C250&ref=nb_sb_noss_1"

wanted_list=["₹53,900","Apple iPhone 12 (64GB) - (Product) RED"]

# %%
scraper=AutoScraper()

result=scraper.build(amazon_url,wanted_list)    ##Wanted_list means what we you to fetch in this case a want to scrape the title and price of iPhone under 1 lakh
print(result)
# Out:
# ['₹1,16,990', '₹1,19,900', '₹79,490', '₹89,900', '₹1,29,900', '₹53,900', '₹65,900', '₹84,880', '₹1,28,999', '₹81,990', '₹95,999', '₹1,350', '₹1,399', '₹1,49,999', '₹1,71,999', '₹88,999', '₹99,999', '₹1,34,000', '₹65,920', '₹99,900', '₹1,49,900', '₹60,299', '₹84,999', '₹58,900', '₹47,999', '₹64,999', 'Apple iPhone 13 Pro (128GB) - Silver', 'Apple iPhone 13 (256GB) - (Product) RED', 'Apple iPhone 13 Pro Max (128GB) - Graphite', 'Apple iPhone 12 (64GB) - (Product) RED', 'Samsung S21 Ultra 5G (Phantom Black, 12GB RAM, 256GB Storage)', 'Samsung Galaxy Z Flip3 5G (Lavender, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers', 'Mantr K33 Card Phone with Dual SIM, 1.44 inch, FM Recording, 800 mAh Removable Battery, Bluetooth DIALER, Vibration, Camera with Flashlight, BIS Certified & 1 Year (Black)', 'Samsung Galaxy Z Fold3 5G (Phantom Green, 12GB RAM, 256GB Storage) with No Cost EMI/Additional Exchange Offers', 'Samsung Galaxy Z Flip3 5G (Phantom Black, 8GB RAM, 256GB Storag
# ...

# %%
scraper.get_result_similar(amazon_url,grouped=True)
# Out:
# {'rule_74g4': ['Apple iPhone 13 Pro (128GB) - Silver',
#   'Apple iPhone 13 (256GB) - (Product) RED',
#   'Apple iPhone 13 Pro Max (128GB) - Graphite',
#   'Apple iPhone 12 (64GB) - (Product) RED',
#   'Samsung S21 Ultra 5G (Phantom Black, 12GB RAM, 256GB Storage)',
#   'Samsung Galaxy Z Flip3 5G (Lavender, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'Mantr K33 Card Phone with Dual SIM, 1.44 inch, FM Recording, 800 mAh Removable Battery, Bluetooth DIALER, Vibration, Camer...',
#   'Samsung Galaxy Z Fold3 5G (Phantom Green, 12GB RAM, 256GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'Samsung Galaxy Z Flip3 5G (Phantom Black, 8GB RAM, 256GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'Samsung Galaxy Z Fold3 with Snapdragon 888 Single Sim (Phantom Silver, 12GB RAM, 512GB Storage)',
#   'Samsung Galaxy Z Flip3 5G with Snapdragon 888 (Phantom Black, 8GB RAM, 128GB Storage)',
#   'Apple iPhone 13 Pro (512GB) - Gold',
# ...

# %%
scraper.set_rule_aliases({'rule_i87q':'Title','rule_o0i0':'Price'})
scraper.keep_rules(['rule_i87q','rule_o0i0'])
scraper.save('amazon-search')

# %%
results=scraper.get_result_similar("https://www.amazon.in/s?k=iphones")

# %%
results
# Out:
# ['₹59,900',
#  '₹70,900',
#  '₹68,900',
#  '₹79,900',
#  '₹46,900',
#  '₹48,900',
#  '₹42,999',
#  '₹57,800',
#  '₹1,19,900',
#  '₹53,900',
#  '₹65,900',
#  '₹52,900',
#  '₹1,39,900',
#  '₹55,900',
#  '₹73,999',
#  '₹79,490',
#  '₹89,900',
#  'Apple iPhone 12 (128GB) - Blue',
#  'Apple iPhone 13 (128GB) - Midnight',
#  'Apple iPhone 13 (128GB) - Blue',
#  'Apple iPhone 13 (128GB) - Starlight',
#  'Apple iPhone 12 (128GB) - Black',
#  'Apple iPhone SE (128 GB) - Midnight (3rd Generation)',
#  'Apple iPhone 13 (128GB) - Pink',
#  'Apple iPhone XR (128GB) - (Product) RED',
#  'Apple iPhone 13 Pro (128 GB) - Alpine Green',
#  'Apple iPhone 13 (128GB) - (Product) RED',
#  'Apple iPhone 12 (64GB) - Blue',
#  'Apple iPhone XR (128GB) - Coral',
#  'Apple iPhone 13 Pro Max (256GB) - Sierra Blue',
#  'Apple iPhone 12 (64GB) - White',
#  'Apple iPhone 13 Mini (256GB) - Midnight',
#  'Apple iPhone 13 (256GB) - Pink']

# %% [markdown]
# **3) Web Scrapping From Cricbuz:**

# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
    
    page=requests.get("https://www.cricbuzz.com/")
except Exception as e:
    error_type, error_obj, error_info=sys.exc_info()
    print("ERROR FOR LINK:", url)
    print(error_type,'Line:', error_info.tb_lineno)
    
time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">LSG now find themselves on top of the points table</div>,
#  <div class="cb-nws-intr">Chahal's 3/28 restricted Punjab despite Bairstow fifty and an unbeaten cameo from Jitesh</div>,
#  <div class="cb-nws-intr">Warner's was a career born in T20. He was "the person thrown out there", the one who legitimised it by reverse-engineering a path to Test cricket</div>,
#  <div class="cb-nws-intr">Kane Williamson is enduring his worst returns with the bat in the IPL and is under scrutiny</div>,
#  <div class="cb-nws-intr">After a string of five wins, Gujarat have now recorded two consecutive losses but it's not time to worry just yet</div>,
#  <div class="cb-nws-intr">It maybe parochial to consider the fate of a cricket ball right now, but when we do count up the casualties of the ongoing war, we may have to include the Ukrainian Cricket Federation</div>,
#  <div class="cb-nws-intr">The five white-ball fixtures will be played in Trinidad, St Kitts and the US</div>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# LSG now find themselves on top of the points table
#
#
# Chahal's 3/28 restricted Punjab despite Bairstow fifty and an unbeaten cameo from Jitesh
#
#
# Warner's was a career born in T20. He was "the person thrown out there", the one who legitimised it by reverse-engineering a path to Test cricket
#
#
# Kane Williamson is enduring his worst returns with the bat in the IPL and is under scrutiny
#
#
# After a string of five wins, Gujarat have now recorded two consecutive losses but it's not time to worry just yet
#
#
# It maybe parochial to consider the fate of a cricket ball right now, but when we do count up the casualties of the ongoing war, we may have to include the Ukrainian Cricket Federation
#
#
# The five white-ball fixtures will be played in Trinidad, St Kitts and the US
#
#
# One of the quickest bowlers in the world, Lockie Ferguson talks about his love for fast bowling, aggression, workload management, and more in an exclusive interview
#
#
# ...

# %% [markdown]
# **4)WebScraping Flipkart Ecommerce:**

# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.flipkart.com/search?q=camera&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
htmlContent=response.content
soup=BeautifulSoup(htmlContent,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6e7580.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %% [markdown]
# *Here are some simple ways to navigate that data structure:

# %%
soup.title
# <title>The Dormouse's story</title>

soup.title.name
# u'title'

soup.title.string
# u'The Dormouse's story'

soup.title.parent.name
# u'head'

soup.p
# <p class="title"><b>The Dormouse's story</b></p>

soup.p['class']
# u'title'

soup.a
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

soup.find_all('a')
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

soup.find(id="link3")
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
print(soup.title)
# Out:
# <title>Camera- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
print(soup.title.name)
# Out:
# title

# %%
print(soup.title.string)
# Out:
# Camera- Buy Products Online at Best Price in India - All Categories | Flipkart.com

# %%
print(soup.title.parent.name)
# Out:
# head

# %% [markdown]
# **To Extract links:**

# %% [markdown]
# * Method signature: find(name, attrs, recursive, string, **kwargs)
#
# * The find_all() method scans the entire document looking for results, but sometimes you only want to find one result. If you know a document only has one tag, it’s a waste of time to scan the entire document looking for more. Rather than passing in limit=1 every time you call find_all, you can use the find() method. These two lines of code are nearly equivalent.

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /plus
# /account/login?ret=/search%3Fq%3Dcamera%26otracker%3Dsearch%26otracker1%3Dsearch%26marketplace%3DFLIPKART%26as-show%3Don%26as%3Doff
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?otracker=Cart_Icon_Click
# /cameras-accessories/pr?sid=jek&q=camera&otracker=categorytree
# /cameras/pr?sid=jek,p31&q=camera&otracker=categorytree
# /cameras/drones/pr?sid=jek,p31,jnp&q=camera&otracker=categorytree
# /cameras/point-and-shoot/pr?sid=jek,p31,nxa&q=camera&otracker=categorytree
# /cameras/ip-cameras/pr?sid=jek,p31,ev1&q=camera&otracker=categorytree
# /cameras/sports-action/pr?sid=jek,p31,s3q&q=camera&otracker=categorytree
# /cameras/instant-cameras/pr?sid=jek,p31,ysu&q=camera&otracker=categorytree
# /
# /cameras-accessories/pr?sid=jek&marketplace=FLIPKART
# /cameras/pr?sid=jek,p31&marketplace=FLIPKART
# ...

# %% [markdown]
# **To Extract Images**

# %%
for image in soup.find_all('img'):
    print(image.get('src'))
# Out:
# //static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_8d85f4.png
# //static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/plus_aef861.png
# https://rukminim2.flixcart.com/image/312/312/jn97frk0/dslr-camera/n/t/g/ilce-7rm3-sony-original-imaf9zhknvjh7ksp.jpeg?q=70
# ...://rukminim2.flixcart.com/image/312/312/l08gsy80/dslr-camera/s/e/b/-original-imagc2cz2hyqgwmn.jpeg?q=70
# ...-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png
# https://rukminim2.flixcart.com/image/312/312/juwzf680/dslr-camera/g/a/q/200d-ii-200d-ii-canon-original-imaffvrhzyqzayys.jpeg?q=70
# ...-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png
# https://rukminim2.flixcart.com/image/312/312/jfbfde80/camera/n/r/n/canon-eos-eos-3000d-dslr-original-imaf3t5h9yuyc5zu.jpeg?q=70
# ...-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png
# ...

# %% [markdown]
# **To Extract Class**

# %%
product=soup.find_all('div',class_="_1AtVbE col-12-12")
print(product)              #To extract class we have to right click on page and then click on inspect
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/cameras-accessories/pr?sid=jek&amp;q=camera&amp;otracker=categorytree" title="Cameras &amp; Accessories">Cameras &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/camer
# ...

# %%
product=soup.find('div',attrs={'class':'_1MR4o5'})
print(product)
# Out:
# <div class="_1MR4o5"><div class="_3GIHBu"><a class="_2whKao" href="/">Home</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/cameras-accessories/pr?sid=jek&amp;marketplace=FLIPKART">Cameras &amp; Accessories</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/cameras/pr?sid=jek,p31&amp;marketplace=FLIPKART">Cameras</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div></div>

# %% [markdown]
# * To store data we pass empty list

# %%
titles=[]
prices=[]

# %% [markdown]
# **To Extract Titles**

# %%
for d in soup.find_all('div',attrs={'class':'_3pLy-c row'}):   #right Click on product  and then inspect and see this product is belong to which div
    title=d.find('div',attrs={'class':'_4rR01T'})              #After see the div and then right click on title and and see which class it has.
    print(title.string)
# Out:
# SONY Alpha 7RM3 Mirrorless Camera Body Only
# SONY ILCE-7M4/BQ IN5 Mirrorless Camera Body Only
# Canon EOS 200D II DSLR Camera EF-S18-55mm IS STM
# Canon EOS 3000D DSLR Camera 1 Camera Body, 18 - 55 mm Lens
# Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS II Lens
# Canon EOS M50 Mark II Mirrorless Camera EF-M15-45mm is STM Lens
# FUJIFILM X Series X-T200 Mirrorless Camera Body with 15-45 mm Lens
# FUJIFILM X Series X-T200 Mirrorless Camera Body with 15-45 mm Lens
# SONY CyberShot DSC-W800/BC IN5
# Visicube Go Pro Action Camera Sports Camera 16MP 4k Wifi Waterproof Action Camera with Multi Language ...
# Canon EOS 6D Mark II DSLR Camera Body with Single Lens: EF24-105mm f/4L IS II USM
# IBS ACTION CAMERA Home Security WiFi Mini Hidden HD 1080P Night Vision Spy Camera Motion Detect Sports...
# Canon EOS R Mirrorless Camera Body only
# IMPLY GO PRO 4K Full HD WiFi 30M Waterproof Sports Action Camera Waterproof DV Camcorder 16MP Sports a...
# ...

# %% [markdown]
# **To Extract Prices**

# %%
for d in soup.find_all('div',attrs={'class':'_3pLy-c row'}):   #right Click on product  and then inspect and see this product is belong to which div
    price=d.find('div',attrs={'class':'_30jeq3 _1_WHN1'})              #After see the div and then right click on price and and see which class it has.
    print(price.string)
# Out:
# ₹2,02,990
# ₹2,42,490
# ₹53,999
# ₹24,999
# ₹33,490
# ₹56,999
# ₹61,999
# ₹61,999
# ₹7,790
# ₹2,449
# ₹1,72,546
# ₹1,149
# ₹1,36,990
# ₹2,499
# ₹1,195
# ₹1,399
# ₹88,546
# ₹4,999
# ₹1,380
# ₹789
# ₹1,499
# ₹1,299
# ₹6,499
# ₹1,199
